# %%
from transformers import BertTokenizer, BertForTokenClassification
from transformers import pipeline

# %%
from langchain_community.document_loaders import PyMuPDFLoader, TextLoader
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from config import Config

def split_documents(file_path, page_start=None, page_end=None, chunk_size=Config.SPLITTER_CHUNK_SIZE, chunk_overlap=Config.SPLITTER_CHUNK_OVERLAP):
    if file_path.endswith('.pdf'):
        loader = PyMuPDFLoader(file_path=file_path)
        doc = loader.load()[page_start:page_end]
    else:
        loader = TextLoader(file_path)
        docs = loader.load()
        doc = [Document(page) for page in docs[0].page_content.split('\n-----\n')[page_start:page_end]]

    if page_start is None:
        page_start = 0
    if page_end is None:
        page_end = len(doc)

    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
    )
    docs = text_splitter.split_documents(doc)
    return docs

# %%
file_path = "documentos/acordaos/0600012-49_REl_28052024_1.txt"
start_page = 2
end_page = 5
doc = split_documents(file_path, start_page, end_page)

# %%
from langchain_community.vectorstores import FAISS
from langchain_ollama import OllamaEmbeddings

from llms import get_llama

llm = get_llama()
embeddings_model = OllamaEmbeddings(
    base_url=Config.OLLAMA_EMBEDDINGS_BASE_URL,
    model=Config.OLLAMA_EMBEDDINGS_MODEL,
)

vectorstore = FAISS.from_documents(documents=doc, embedding=embeddings_model)
retriever = vectorstore.as_retriever()

# %%
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.prompts import PromptTemplate

prompt = PromptTemplate.from_template(
    """
    Você é um especialista jurídico com foco em simplificação de textos legais. Sua tarefa é analisar acórdãos judiciais e gerar um resumo simplificado, acessível ao público geral, sem perder a precisão jurídica. O formato do documento simplificado deve ser claro, objetivo e seguir uma estrutura pré-definida.
    Preencha o acórdão simplificado utilizando as informações fornecidas em cada bloco. Siga o formato abaixo para garantir que todos os elementos necessários sejam cobertos e organizados conforme a estrutura do acórdão:
    Responda com o texto simplificado do acórdão, e nada mais.

    ### FORMATO
    ```
    **Relatório (O Caso)**: Resuma de forma objetiva os fatos apresentados no acórdão, destacando em 3 parágrafos, com no máximo 3 linhas cada um, e, quando for o caso, caixa de texto explicativa, tudo em texto contínuo.

    Informações iniciais do processo analisado pelo juiz: indique o que o autor do recurso pediu e o que o réu alegou para se defender.
    Decisão do juiz no processo inicial: Apresente a decisão do juiz no processo inicial, descrevendo o que o juiz decidiu e as justificativas legais usadas.
    Artigos de lei e fundamentos jurídicos relevantes: cite artigos de lei e fundamentos jurídicos relevantes..
    Quem recorreu e o que alegou: indique quem recorreu à decisão e o que alegou para recorrer.

    Caixa de texto explicativa com termos jurídicos relevantes para a compreensão do assunto principal: forneça definições e explicações simples de termos, expressões ou assuntos jurídicos relevantes para a compreensão do assunto principal. Exemplo: “Propaganda antecipada negativa: A propaganda eleitoral antecipada negativa acontece quando, antes de 16 de agosto do ano eleitoral (art. 36 da Lei nº 9.504/1997), alguém faz críticas para prejudicar adversários políticos e influenciar eleitores. Essa prática é proibida e pode resultar em multa”.
    ```
    ### FIM DO FORMATO

    ### CONTEXTO
    ```
    {context}
    ```
    ### FIM DO CONTEXTO
    """
)

stuff_chain = create_stuff_documents_chain(llm, prompt)
retrieval_chain = create_retrieval_chain(retriever, stuff_chain)

chunks = []
for chunk in retrieval_chain.stream({"input": "Comece."}):
    answer = chunk.get('answer', '')
    chunks.append(answer)
    print(answer, end='', flush=True)
print()
# Out:
# **Relatório (O Caso)**: O caso envolve um recurso eleitoral apresentado pelo candidato Ilomar, que alega que sua pré-candidatura foi prejudicada pela realização de propaganda eleitoral antecipada. O juiz decidiu que o ato do candidato Ilomar foi caracterizado como propaganda eleitoral antecipada e imposta a penalidade do artigo 36, § 3º, da Lei 9.504/97.
#
# **Informações iniciais do processo**: O autor do recurso pediu a anulação da decisão do juiz que considerou a propaganda eleitoral antecipada e a aplicação da penalidade. O réu alegou que não havia pedido explícito de votos ou conduta que prejudicasse a igualdade entre os candidatos.
#
# **Decisão do juiz no processo inicial**: O juiz decidiu que o ato do candidato Ilomar foi caracterizado como propaganda eleitoral antecipada e imposta a penalidade do artigo 36, § 3º, da Lei 9.504/97.
#
# **Artigos de lei e fundamentos jurídicos relevantes**: O artigo 36 da Lei 9.504/97 proíbe a propaganda eleitoral antecipada, que é definida como a realização de atos de propaganda antes do período autorizado pela legislação.
#
# **Quem recorreu e o que alegou**: O candidato Ilomar recorreu à decisão do juiz, alegando que sua pré-candidatura foi prejudicada pela propaganda eleitoral antecipada. Ele também argumentou que não havia pedido explícito de votos ou conduta que prejudicasse a igualdade entre os candidatos.
#
# **Caixa de texto explicativa**: Propaganda antecipada negativa: A propaganda eleitoral antecipada negativa acontece quando, antes de 16 de agosto do ano eleitoral (art. 36 da Lei nº 9.504/1997), alguém faz críticas para prejudicar adversários políticos e influenciar eleitores. Essa prática é proibida e pode resultar em multa.
#
# **Conclusão**: O caso envolve uma disputa sobre a propaganda eleitoral antecipada e sua aplicação à penalidade. A decisão do juiz foi baseada na interpretação da lei e nos fatos apresentados no processo.

# %%
res = "".join(chunks)
summary = res
summary
# Out:
# '**Relatório (O Caso)**: O caso envolve um recurso eleitoral apresentado pelo candidato Ilomar, que alega que sua pré-candidatura foi prejudicada pela realização de propaganda eleitoral antecipada. O juiz decidiu que o ato do candidato Ilomar foi caracterizado como propaganda eleitoral antecipada e imposta a penalidade do artigo 36, § 3º, da Lei 9.504/97.\n\n**Informações iniciais do processo**: O autor do recurso pediu a anulação da decisão do juiz que considerou a propaganda eleitoral antecipada e a aplicação da penalidade. O réu alegou que não havia pedido explícito de votos ou conduta que prejudicasse a igualdade entre os candidatos.\n\n**Decisão do juiz no processo inicial**: O juiz decidiu que o ato do candidato Ilomar foi caracterizado como propaganda eleitoral antecipada e imposta a penalidade do artigo 36, § 3º, da Lei 9.504/97.\n\n**Artigos de lei e fundamentos jurídicos relevantes**: O artigo 36 da Lei 9.504/97 proíbe a propaganda eleitoral antecipada, que é definida como a realização de atos de propaganda antes do período autorizado pela legislação.\n\n**Quem recorreu e o que alegou**: O candidato Ilomar recorreu à decisão do juiz, alegando que sua pré-candidatura foi prejudicada pela propaganda eleitoral antecipada. Ele também argumentou que não havia pedido explícito de votos ou conduta que prejudicasse a igualdade entre os candidatos.\n\n**Caixa de texto explicativa**: Propaganda antecipada negativa: A propaganda eleitoral antecipada negativa acontece quando, antes de 16 de agosto do ano eleitoral (art. 36 da Lei nº 9.504/1997), alguém faz críticas para prejudicar adversários políticos e influenciar eleitores. Essa prática é proibida e pode resultar em multa.\n\n**Conclusão**: O caso envolve uma disputa sobre a propaganda eleitoral antecipada e sua aplicação à penalidade. A decisão do juiz foi baseada na interpretação da lei e nos fatos apresentados no processo.'

# %%
from ner import NER

ner = NER()
pipeline = ner.ner

# %%
all_entities = [ner(chunk.page_content) for chunk in doc]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 all_entities = [ner(chunk.page_content) for chunk in doc]
#
# NameError: name 'doc' is not defined

# %%
all_entities_flattened = [entity for entities in all_entities for entity in entities]
all_entities_flattened
# Out:
# [{'entity': 'B-PESSOA',
#   'score': 0.99925846,
#   'index': 8,
#   'word': 'AN',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.9995012,
#   'index': 9,
#   'word': '##T',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.9996137,
#   'index': 10,
#   'word': '##Ô',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.99947196,
#   'index': 11,
#   'word': '##N',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.9993319,
#   'index': 12,
#   'word': '##IO',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.99985313,
#   'index': 13,
#   'word': 'I',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.99988854,
#   'index': 14,
#   'word': '##LO',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.99989414,
#   'index': 15,
#   'word': '##MA',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998938,
#   'index': 16,
#   'word': '##R',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9999063,
#   'index': 17,
#   'word': 'V',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.99990237,
#   'index': 18,
#   'word': '##AS',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998938,
#   'index': 19,
#   'word': '##CO',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998987,
#   'index': 20,
#   'word': '##N',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998969,
#   'index': 21,
#   'word': '##CE',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998946,
#   'index': 22,
#   'word': '##LO',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998796,
#   'index': 23,
#   'word': '##S',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.99986744,
#   'index': 24,
#   'word': 'CR',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.999887,
#   'index': 25,
#   'word': '##U',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9997223,
#   'index': 26,
#   'word': '##Z',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.9996865,
#   'index': 38,
#   'word': 'F',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.9997155,
#   'index': 39,
#   'word': '##RA',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.99969757,
#   'index': 40,
#   'word': '##N',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.9997392,
#   'index': 41,
#   'word': '##CI',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.99967146,
#   'index': 42,
#   'word': '##SC',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.99963164,
#   'index': 43,
#   'word': '##O',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998671,
#   'index': 44,
#   'word': 'J',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.99987197,
#   'index': 45,
#   'word': '##AR',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.999879,
#   'index': 46,
#   'word': '##DE',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998796,
#   'index': 47,
#   'word': '##L',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.99988866,
#   'index': 48,
#   'word': 'R',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.99988973,
#   'index': 49,
#   'word': '##O',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.99988806,
#   'index': 50,
#   'word': '##DR',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998919,
#   'index': 51,
#   'word': '##IG',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.99988675,
#   'index': 52,
#   'word': '##U',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998697,
#   'index': 53,
#   'word': '##ES',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998853,
#   'index': 54,
#   'word': 'DE',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.99986434,
#   'index': 55,
#   'word': 'SO',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.99986625,
#   'index': 56,
#   'word': '##US',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998155,
#   'index': 57,
#   'word': '##A',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.9823401,
#   'index': 59,
#   'word': 'O',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.97908086,
#   'index': 60,
#   'word': '##AB',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.9991904,
#   'index': 73,
#   'word': 'CA',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.99945945,
#   'index': 74,
#   'word': '##VA',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.9994025,
#   'index': 75,
#   'word': '##LC',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.99931157,
#   'index': 76,
#   'word': '##AN',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.99903333,
#   'index': 77,
#   'word': '##TE',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.99983895,
#   'index': 78,
#   'word': 'M',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.99987066,
#   'index': 79,
#   'word': '##EN',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.99987435,
#   'index': 80,
#   'word': '##DO',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.999864,
#   'index': 81,
#   'word': '##N',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998466,
#   'index': 82,
#   'word': '##Ç',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998585,
#   'index': 83,
#   'word': '##A',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.99987304,
#   'index': 84,
#   'word': 'VI',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998522,
#   'index': 85,
#   'word': '##EI',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998317,
#   'index': 86,
#   'word': '##RA',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.9911596,
#   'index': 88,
#   'word': 'O',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.98567027,
#   'index': 89,
#   'word': '##AB',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.999579,
#   'index': 101,
#   'word': 'M',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.99957544,
#   'index': 102,
#   'word': '##IN',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.9996296,
#   'index': 103,
#   'word': '##IS',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.99955946,
#   'index': 104,
#   'word': '##T',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.99962854,
#   'index': 105,
#   'word': '##É',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.99960345,
#   'index': 106,
#   'word': '##RI',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.99959546,
#   'index': 107,
#   'word': '##O',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.9995752,
#   'index': 108,
#   'word': 'P',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.9996687,
#   'index': 109,
#   'word': '##Ú',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.99968326,
#   'index': 110,
#   'word': '##B',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.9996811,
#   'index': 111,
#   'word': '##L',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.9996747,
#   'index': 112,
#   'word': '##IC',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.99961483,
#   'index': 113,
#   'word': '##O',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.9996257,
#   'index': 114,
#   'word': 'E',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.99919885,
#   'index': 115,
#   'word': '##L',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.99959916,
#   'index': 116,
#   'word': '##EI',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.9995191,
#   'index': 117,
#   'word': '##TO',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.99962664,
#   'index': 118,
#   'word': '##RA',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.99915874,
#   'index': 119,
#   'word': '##L',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.9994773,
#   'index': 142,
#   'word': 'AN',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.9996049,
#   'index': 143,
#   'word': '##T',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.99962103,
#   'index': 144,
#   'word': '##Ô',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.9996019,
#   'index': 145,
#   'word': '##N',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.9994136,
#   'index': 146,
#   'word': '##IO',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.999806,
#   'index': 147,
#   'word': 'I',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998828,
#   'index': 148,
#   'word': '##LO',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.999871,
#   'index': 149,
#   'word': '##MA',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.99986076,
#   'index': 150,
#   'word': '##R',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9999032,
#   'index': 151,
#   'word': 'V',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.99990094,
#   'index': 152,
#   'word': '##AS',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998982,
#   'index': 153,
#   'word': '##CO',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9999001,
#   'index': 154,
#   'word': '##N',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998988,
#   'index': 155,
#   'word': '##CE',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.99989724,
#   'index': 156,
#   'word': '##LO',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998908,
#   'index': 157,
#   'word': '##S',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998838,
#   'index': 158,
#   'word': 'CR',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.99988806,
#   'index': 159,
#   'word': '##U',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998369,
#   'index': 160,
#   'word': '##Z',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.59226924,
#   'index': 172,
#   'word': '[UNK]',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.75500184,
#   'index': 173,
#   'word': 'Zona',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.99546695,
#   'index': 175,
#   'word': 'Can',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.99711096,
#   'index': 176,
#   'word': '##ind',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.9941713,
#   'index': 177,
#   'word': '##é',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.9543733,
#   'index': 178,
#   'word': '/',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.9664239,
#   'index': 179,
#   'word': 'CE',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LEGISLACAO',
#   'score': 0.99946004,
#   'index': 40,
#   'word': 'art',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99939096,
#   'index': 41,
#   'word': '.',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99920267,
#   'index': 42,
#   'word': '36',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9996611,
#   'index': 43,
#   'word': ',',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9997309,
#   'index': 44,
#   'word': '§',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99962425,
#   'index': 45,
#   'word': '[UNK]',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99966,
#   'index': 46,
#   'word': ',',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9996486,
#   'index': 47,
#   'word': 'da',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9995863,
#   'index': 48,
#   'word': 'Lei',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9993926,
#   'index': 49,
#   'word': '9',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9994981,
#   'index': 50,
#   'word': '.',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9995172,
#   'index': 51,
#   'word': '50',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99948585,
#   'index': 52,
#   'word': '##4',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99926084,
#   'index': 53,
#   'word': '/',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9991386,
#   'index': 54,
#   'word': '97',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.9989178,
#   'index': 61,
#   'word': 'Promo',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.99922585,
#   'index': 62,
#   'word': '##toria',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.9952324,
#   'index': 63,
#   'word': 'Eleitoral',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.99769294,
#   'index': 64,
#   'word': 'da',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.9991492,
#   'index': 65,
#   'word': '[UNK]',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.9993343,
#   'index': 66,
#   'word': 'Zona',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.99921894,
#   'index': 67,
#   'word': '/',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.99942267,
#   'index': 68,
#   'word': 'CE',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.9712327,
#   'index': 1,
#   'word': 'Can',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.97102106,
#   'index': 2,
#   'word': '##ind',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.977221,
#   'index': 3,
#   'word': '##é',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.93677944,
#   'index': 29,
#   'word': 'Insta',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.95223826,
#   'index': 30,
#   'word': '##gram',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.6034735,
#   'index': 41,
#   'word': 'il',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.68814117,
#   'index': 42,
#   'word': '##om',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LEGISLACAO',
#   'score': 0.9994918,
#   'index': 39,
#   'word': 'art',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.999129,
#   'index': 40,
#   'word': '.',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99908924,
#   'index': 41,
#   'word': '36',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9990644,
#   'index': 42,
#   'word': '-',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9990018,
#   'index': 43,
#   'word': 'A',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99949706,
#   'index': 44,
#   'word': 'da',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99946624,
#   'index': 45,
#   'word': 'Lei',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99933416,
#   'index': 46,
#   'word': '9',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9994361,
#   'index': 47,
#   'word': '.',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99943763,
#   'index': 48,
#   'word': '50',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99945074,
#   'index': 49,
#   'word': '##4',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99915624,
#   'index': 50,
#   'word': '/',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9991671,
#   'index': 51,
#   'word': '97',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LEGISLACAO',
#   'score': 0.9994784,
#   'index': 99,
#   'word': 'art',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99873775,
#   'index': 100,
#   'word': '.',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9990138,
#   'index': 101,
#   'word': '36',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9989642,
#   'index': 102,
#   'word': '-',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99897134,
#   'index': 103,
#   'word': 'A',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9993857,
#   'index': 104,
#   'word': 'da',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9993969,
#   'index': 105,
#   'word': 'Lei',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9992242,
#   'index': 106,
#   'word': '[UNK]',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99923897,
#   'index': 107,
#   'word': '9',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99939823,
#   'index': 108,
#   'word': '.',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99940443,
#   'index': 109,
#   'word': '50',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99942636,
#   'index': 110,
#   'word': '##4',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9991456,
#   'index': 111,
#   'word': '/',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99919635,
#   'index': 112,
#   'word': '97',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.577895,
#   'index': 27,
#   'word': 'assentamento',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.9965127,
#   'index': 47,
#   'word': 'Il',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.99690646,
#   'index': 48,
#   'word': '##om',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.99639577,
#   'index': 49,
#   'word': '##ar',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.9943779,
#   'index': 56,
#   'word': 'Can',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.99640757,
#   'index': 57,
#   'word': '##ind',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.9886579,
#   'index': 58,
#   'word': '##é',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.96786433,
#   'index': 68,
#   'word': 'Can',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.99002445,
#   'index': 69,
#   'word': '##ind',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.94368166,
#   'index': 70,
#   'word': '##é',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.7977132,
#   'index': 30,
#   'word': 'I',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.82532483,
#   'index': 31,
#   'word': '##L',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.7467757,
#   'index': 32,
#   'word': '##IO',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.67267346,
#   'index': 33,
#   'word': '##MA',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.7916356,
#   'index': 34,
#   'word': '##R',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.9948596,
#   'index': 38,
#   'word': 'Can',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.99693394,
#   'index': 39,
#   'word': '##ind',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.98837936,
#   'index': 40,
#   'word': '##é',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.9912493,
#   'index': 35,
#   'word': 'interior',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LOCAL',
#   'score': 0.9915759,
#   'index': 36,
#   'word': 'do',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LOCAL',
#   'score': 0.97785646,
#   'index': 37,
#   'word': 'Ceará',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.99770564,
#   'index': 62,
#   'word': 'T',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.9965856,
#   'index': 63,
#   'word': '##SE',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.86496294,
#   'index': 92,
#   'word': 'Promo',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.83591986,
#   'index': 93,
#   'word': '##toria',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.6711355,
#   'index': 94,
#   'word': 'Eleitoral',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.9949079,
#   'index': 19,
#   'word': 'município',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LOCAL',
#   'score': 0.8713211,
#   'index': 20,
#   'word': 'de',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LOCAL',
#   'score': 0.6641886,
#   'index': 21,
#   'word': 'Can',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LOCAL',
#   'score': 0.71379435,
#   'index': 22,
#   'word': '##ind',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LOCAL',
#   'score': 0.9066679,
#   'index': 23,
#   'word': '##é',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.984097,
#   'index': 4,
#   'word': 'Procurador',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.9909554,
#   'index': 5,
#   'word': '##ia',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.99087584,
#   'index': 6,
#   'word': 'Regional',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.9944042,
#   'index': 7,
#   'word': 'Eleitoral',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LEGISLACAO',
#   'score': 0.9995522,
#   'index': 31,
#   'word': 'art',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9994617,
#   'index': 32,
#   'word': '.',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99927574,
#   'index': 33,
#   'word': '36',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99970007,
#   'index': 34,
#   'word': ',',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99977463,
#   'index': 35,
#   'word': '§',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99971634,
#   'index': 36,
#   'word': '[UNK]',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9997185,
#   'index': 37,
#   'word': ',',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99966633,
#   'index': 38,
#   'word': 'da',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.999652,
#   'index': 39,
#   'word': 'Lei',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9994623,
#   'index': 40,
#   'word': '9',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99952424,
#   'index': 41,
#   'word': '.',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9995432,
#   'index': 42,
#   'word': '50',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99952245,
#   'index': 43,
#   'word': '##4',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9993174,
#   'index': 44,
#   'word': '/',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99924517,
#   'index': 45,
#   'word': '97',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LEGISLACAO',
#   'score': 0.9993337,
#   'index': 65,
#   'word': 'art',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9991985,
#   'index': 66,
#   'word': '.',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99927706,
#   'index': 67,
#   'word': '36',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9992347,
#   'index': 68,
#   'word': '-',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9991658,
#   'index': 69,
#   'word': 'A',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99944645,
#   'index': 70,
#   'word': 'da',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99947804,
#   'index': 71,
#   'word': 'Lei',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99931574,
#   'index': 72,
#   'word': '9',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99939156,
#   'index': 73,
#   'word': '.',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99949014,
#   'index': 74,
#   'word': '50',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.99948573,
#   'index': 75,
#   'word': '##4',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.999141,
#   'index': 76,
#   'word': '/',
#   'start': None,
#   'end': None},
#  {'entity': 'I-LEGISLACAO',
#   'score': 0.9991792,
#   'index': 77,
#   'word': '97',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.9984425,
#   'index': 99,
#   'word': 'Fortaleza',
#   'start': None,
#   'end': None},
#  {'entity': 'B-TEMPO',
#   'score': 0.9993948,
#   'index': 101,
#   'word': '28',
#   'start': None,
#   'end': None},
#  {'entity': 'I-TEMPO',
#   'score': 0.9997023,
#   'index': 102,
#   'word': 'de',
#   'start': None,
#   'end': None},
#  {'entity': 'I-TEMPO',
#   'score': 0.99962103,
#   'index': 103,
#   'word': 'maio',
#   'start': None,
#   'end': None},
#  {'entity': 'I-TEMPO',
#   'score': 0.99949265,
#   'index': 104,
#   'word': 'de',
#   'start': None,
#   'end': None},
#  {'entity': 'I-TEMPO',
#   'score': 0.9992532,
#   'index': 105,
#   'word': '202',
#   'start': None,
#   'end': None},
#  {'entity': 'I-TEMPO',
#   'score': 0.9981192,
#   'index': 106,
#   'word': '##4',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.9995245,
#   'index': 121,
#   'word': 'D',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.9996822,
#   'index': 122,
#   'word': '##AN',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.99974674,
#   'index': 123,
#   'word': '##I',
#   'start': None,
#   'end': None},
#  {'entity': 'B-PESSOA',
#   'score': 0.9996897,
#   'index': 124,
#   'word': '##EL',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998716,
#   'index': 125,
#   'word': 'CA',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.999863,
#   'index': 126,
#   'word': '##R',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998821,
#   'index': 127,
#   'word': '##VA',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.99985945,
#   'index': 128,
#   'word': '##L',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.999858,
#   'index': 129,
#   'word': '##HO',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998522,
#   'index': 130,
#   'word': 'CA',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998361,
#   'index': 131,
#   'word': '##R',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.99984145,
#   'index': 132,
#   'word': '##N',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.9998528,
#   'index': 133,
#   'word': '##EI',
#   'start': None,
#   'end': None},
#  {'entity': 'I-PESSOA',
#   'score': 0.99972576,
#   'index': 134,
#   'word': '##RO',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.99955565,
#   'index': 18,
#   'word': 'T',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.9996215,
#   'index': 19,
#   'word': '##RI',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.99963486,
#   'index': 20,
#   'word': '##B',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.9996247,
#   'index': 21,
#   'word': '##UN',
#   'start': None,
#   'end': None},
#  {'entity': 'B-ORGANIZACAO',
#   'score': 0.9995913,
#   'index': 22,
#   'word': '##AL',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.9998623,
#   'index': 23,
#   'word': 'R',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.99986005,
#   'index': 24,
#   'word': '##E',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.99985445,
#   'index': 25,
#   'word': '##G',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.99985194,
#   'index': 26,
#   'word': '##IO',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.99985063,
#   'index': 27,
#   'word': '##NA',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.99985707,
#   'index': 28,
#   'word': '##L',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.99985623,
#   'index': 29,
#   'word': 'E',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.9998442,
#   'index': 30,
#   'word': '##L',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.9998542,
#   'index': 31,
#   'word': '##EI',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.9998487,
#   'index': 32,
#   'word': '##TO',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.9998661,
#   'index': 33,
#   'word': '##RA',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.9998535,
#   'index': 34,
#   'word': '##L',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.99978584,
#   'index': 35,
#   'word': 'DO',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.9998153,
#   'index': 36,
#   'word': 'CE',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.99979216,
#   'index': 37,
#   'word': '##AR',
#   'start': None,
#   'end': None},
#  {'entity': 'I-ORGANIZACAO',
#   'score': 0.99977,
#   'index': 38,
#   'word': '##Á',
#   'start': None,
#   'end': None},
#  {'entity': 'B-JURISPRUDENCIA',
#   'score': 0.9989009,
#   'index': 39,
#   'word': 'R',
#   'start': None,
#   'end': None},
#  {'entity': 'B-JURISPRUDENCIA',
#   'score': 0.9991799,
#   'index': 40,
#   'word': '##EC',
#   'start': None,
#   'end': None},
#  {'entity': 'B-JURISPRUDENCIA',
#   'score': 0.999124,
#   'index': 41,
#   'word': '##UR',
#   'start': None,
#   'end': None},
#  {'entity': 'B-JURISPRUDENCIA',
#   'score': 0.99915123,
#   'index': 42,
#   'word': '##SO',
#   'start': None,
#   'end': None},
#  {'entity': 'I-JURISPRUDENCIA',
#   'score': 0.9993686,
#   'index': 43,
#   'word': 'E',
#   'start': None,
#   'end': None},
#  {'entity': 'I-JURISPRUDENCIA',
#   'score': 0.9993411,
#   'index': 44,
#   'word': '##L',
#   'start': None,
#   'end': None},
#  {'entity': 'I-JURISPRUDENCIA',
#   'score': 0.99953437,
#   'index': 45,
#   'word': '##EI',
#   'start': None,
#   'end': None},
#  {'entity': 'I-JURISPRUDENCIA',
#   'score': 0.9995927,
#   'index': 46,
#   'word': '##TO',
#   'start': None,
#   'end': None},
#  {'entity': 'I-JURISPRUDENCIA',
#   'score': 0.99964404,
#   'index': 47,
#   'word': '##RA',
#   'start': None,
#   'end': None},
#  {'entity': 'I-JURISPRUDENCIA',
#   'score': 0.99964905,
#   'index': 48,
#   'word': '##L',
#   'start': None,
#   'end': None},
#  {'entity': 'I-JURISPRUDENCIA',
#   'score': 0.9996903,
#   'index': 49,
#   'word': 'N',
#   'start': None,
#   'end': None},
#  {'entity': 'I-JURISPRUDENCIA',
#   'score': 0.9997043,
#   'index': 50,
#   'word': '.',
#   'start': None,
#   'end': None},
#  {'entity': 'I-JURISPRUDENCIA',
#   'score': 0.9997292,
#   'index': 51,
#   'word': '06',
#   'start': None,
#   'end': None},
#  {'entity': 'I-JURISPRUDENCIA',
#   'score': 0.99972194,
#   'index': 52,
#   'word': '##000',
#   'start': None,
#   'end': None},
#  {'entity': 'I-JURISPRUDENCIA',
#   'score': 0.9996983,
#   'index': 53,
#   'word': '##12',
#   'start': None,
#   'end': None},
#  {'entity': 'I-JURISPRUDENCIA',
#   'score': 0.9997553,
#   'index': 54,
#   'word': '-',
#   'start': None,
#   'end': None},
#  {'entity': 'I-JURISPRUDENCIA',
#   'score': 0.9997043,
#   'index': 55,
#   'word': '49',
#   'start': None,
#   'end': None},
#  {'entity': 'I-JURISPRUDENCIA',
#   'score': 0.99971443,
#   'index': 56,
#   'word': '.',
#   'start': None,
#   'end': None},
#  {'entity': 'I-JURISPRUDENCIA',
#   'score': 0.9997149,
#   'index': 57,
#   'word': '202',
#   'start': None,
#   'end': None},
#  {'entity': 'I-JURISPRUDENCIA',
#   'score': 0.999694,
#   'index': 58,
#   'word': '##4',
#   'start': None,
#   'end': None},
#  {'entity': 'I-JURISPRUDENCIA',
#   'score': 0.99971646,
#   'index': 59,
#   'word': '.',
#   'start': None,
#   'end': None},
#  {'entity': 'I-JURISPRUDENCIA',
#   'score': 0.99966764,
#   'index': 60,
#   'word': '6',
#   'start': None,
#   'end': None},
#  {'entity': 'I-JURISPRUDENCIA',
#   'score': 0.99966633,
#   'index': 61,
#   'word': '.',
#   'start': None,
#   'end': None},
#  {'entity': 'I-JURISPRUDENCIA',
#   'score': 0.9996056,
#   'index': 62,
#   'word': '06',
#   'start': None,
#   'end': None},
#  {'entity': 'I-JURISPRUDENCIA',
#   'score': 0.99964595,
#   'index': 63,
#   'word': '.',
#   'start': None,
#   'end': None},
#  {'entity': 'I-JURISPRUDENCIA',
#   'score': 0.9995534,
#   'index': 64,
#   'word': '00',
#   'start': None,
#   'end': None},
#  {'entity': 'I-JURISPRUDENCIA',
#   'score': 0.99955136,
#   'index': 65,
#   'word': '##33',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.9983835,
#   'index': 71,
#   'word': 'CA',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.99871683,
#   'index': 72,
#   'word': '##N',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.99886703,
#   'index': 73,
#   'word': '##IN',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.99876463,
#   'index': 74,
#   'word': '##D',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.9985751,
#   'index': 75,
#   'word': '##É',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.9988392,
#   'index': 76,
#   'word': '/',
#   'start': None,
#   'end': None},
#  {'entity': 'B-LOCAL',
#   'score': 0.9971311,
#   'index': 77,
#   'word': 'CE',
#   'start': None,
#   'end': None}]

# %%
import pprint


pprint.pprint(all_entities)
# Out:
# [[{'end': None,
#    'entity': 'B-PESSOA',
#    'index': 8,
#    'score': 0.99925846,
#    'start': None,
#    'word': 'AN'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 9,
#    'score': 0.9995012,
#    'start': None,
#    'word': '##T'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 10,
#    'score': 0.9996137,
#    'start': None,
#    'word': '##Ô'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 11,
#    'score': 0.99947196,
#    'start': None,
#    'word': '##N'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 12,
#    'score': 0.9993319,
#    'start': None,
#    'word': '##IO'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 13,
#    'score': 0.99985313,
#    'start': None,
#    'word': 'I'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 14,
#    'score': 0.99988854,
#    'start': None,
#    'word': '##LO'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 15,
#    'score': 0.99989414,
#    'start': None,
#    'word': '##MA'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 16,
#    'score': 0.9998938,
#    'start': None,
#    'word': '##R'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 17,
#    'score': 0.9999063,
#    'start': None,
#    'word': 'V'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 18,
#    'score': 0.99990237,
#    'start': None,
#    'word': '##AS'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 19,
#    'score': 0.9998938,
#    'start': None,
#    'word': '##CO'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 20,
#    'score': 0.9998987,
#    'start': None,
#    'word': '##N'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 21,
#    'score': 0.9998969,
#    'start': None,
#    'word': '##CE'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 22,
#    'score': 0.9998946,
#    'start': None,
#    'word': '##LO'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 23,
#    'score': 0.9998796,
#    'start': None,
#    'word': '##S'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 24,
#    'score': 0.99986744,
#    'start': None,
#    'word': 'CR'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 25,
#    'score': 0.999887,
#    'start': None,
#    'word': '##U'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 26,
#    'score': 0.9997223,
#    'start': None,
#    'word': '##Z'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 38,
#    'score': 0.9996865,
#    'start': None,
#    'word': 'F'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 39,
#    'score': 0.9997155,
#    'start': None,
#    'word': '##RA'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 40,
#    'score': 0.99969757,
#    'start': None,
#    'word': '##N'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 41,
#    'score': 0.9997392,
#    'start': None,
#    'word': '##CI'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 42,
#    'score': 0.99967146,
#    'start': None,
#    'word': '##SC'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 43,
#    'score': 0.99963164,
#    'start': None,
#    'word': '##O'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 44,
#    'score': 0.9998671,
#    'start': None,
#    'word': 'J'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 45,
#    'score': 0.99987197,
#    'start': None,
#    'word': '##AR'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 46,
#    'score': 0.999879,
#    'start': None,
#    'word': '##DE'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 47,
#    'score': 0.9998796,
#    'start': None,
#    'word': '##L'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 48,
#    'score': 0.99988866,
#    'start': None,
#    'word': 'R'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 49,
#    'score': 0.99988973,
#    'start': None,
#    'word': '##O'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 50,
#    'score': 0.99988806,
#    'start': None,
#    'word': '##DR'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 51,
#    'score': 0.9998919,
#    'start': None,
#    'word': '##IG'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 52,
#    'score': 0.99988675,
#    'start': None,
#    'word': '##U'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 53,
#    'score': 0.9998697,
#    'start': None,
#    'word': '##ES'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 54,
#    'score': 0.9998853,
#    'start': None,
#    'word': 'DE'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 55,
#    'score': 0.99986434,
#    'start': None,
#    'word': 'SO'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 56,
#    'score': 0.99986625,
#    'start': None,
#    'word': '##US'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 57,
#    'score': 0.9998155,
#    'start': None,
#    'word': '##A'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 59,
#    'score': 0.9823401,
#    'start': None,
#    'word': 'O'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 60,
#    'score': 0.97908086,
#    'start': None,
#    'word': '##AB'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 73,
#    'score': 0.9991904,
#    'start': None,
#    'word': 'CA'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 74,
#    'score': 0.99945945,
#    'start': None,
#    'word': '##VA'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 75,
#    'score': 0.9994025,
#    'start': None,
#    'word': '##LC'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 76,
#    'score': 0.99931157,
#    'start': None,
#    'word': '##AN'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 77,
#    'score': 0.99903333,
#    'start': None,
#    'word': '##TE'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 78,
#    'score': 0.99983895,
#    'start': None,
#    'word': 'M'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 79,
#    'score': 0.99987066,
#    'start': None,
#    'word': '##EN'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 80,
#    'score': 0.99987435,
#    'start': None,
#    'word': '##DO'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 81,
#    'score': 0.999864,
#    'start': None,
#    'word': '##N'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 82,
#    'score': 0.9998466,
#    'start': None,
#    'word': '##Ç'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 83,
#    'score': 0.9998585,
#    'start': None,
#    'word': '##A'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 84,
#    'score': 0.99987304,
#    'start': None,
#    'word': 'VI'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 85,
#    'score': 0.9998522,
#    'start': None,
#    'word': '##EI'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 86,
#    'score': 0.9998317,
#    'start': None,
#    'word': '##RA'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 88,
#    'score': 0.9911596,
#    'start': None,
#    'word': 'O'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 89,
#    'score': 0.98567027,
#    'start': None,
#    'word': '##AB'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 101,
#    'score': 0.999579,
#    'start': None,
#    'word': 'M'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 102,
#    'score': 0.99957544,
#    'start': None,
#    'word': '##IN'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 103,
#    'score': 0.9996296,
#    'start': None,
#    'word': '##IS'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 104,
#    'score': 0.99955946,
#    'start': None,
#    'word': '##T'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 105,
#    'score': 0.99962854,
#    'start': None,
#    'word': '##É'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 106,
#    'score': 0.99960345,
#    'start': None,
#    'word': '##RI'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 107,
#    'score': 0.99959546,
#    'start': None,
#    'word': '##O'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 108,
#    'score': 0.9995752,
#    'start': None,
#    'word': 'P'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 109,
#    'score': 0.9996687,
#    'start': None,
#    'word': '##Ú'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 110,
#    'score': 0.99968326,
#    'start': None,
#    'word': '##B'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 111,
#    'score': 0.9996811,
#    'start': None,
#    'word': '##L'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 112,
#    'score': 0.9996747,
#    'start': None,
#    'word': '##IC'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 113,
#    'score': 0.99961483,
#    'start': None,
#    'word': '##O'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 114,
#    'score': 0.9996257,
#    'start': None,
#    'word': 'E'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 115,
#    'score': 0.99919885,
#    'start': None,
#    'word': '##L'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 116,
#    'score': 0.99959916,
#    'start': None,
#    'word': '##EI'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 117,
#    'score': 0.9995191,
#    'start': None,
#    'word': '##TO'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 118,
#    'score': 0.99962664,
#    'start': None,
#    'word': '##RA'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 119,
#    'score': 0.99915874,
#    'start': None,
#    'word': '##L'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 142,
#    'score': 0.9994773,
#    'start': None,
#    'word': 'AN'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 143,
#    'score': 0.9996049,
#    'start': None,
#    'word': '##T'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 144,
#    'score': 0.99962103,
#    'start': None,
#    'word': '##Ô'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 145,
#    'score': 0.9996019,
#    'start': None,
#    'word': '##N'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 146,
#    'score': 0.9994136,
#    'start': None,
#    'word': '##IO'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 147,
#    'score': 0.999806,
#    'start': None,
#    'word': 'I'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 148,
#    'score': 0.9998828,
#    'start': None,
#    'word': '##LO'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 149,
#    'score': 0.999871,
#    'start': None,
#    'word': '##MA'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 150,
#    'score': 0.99986076,
#    'start': None,
#    'word': '##R'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 151,
#    'score': 0.9999032,
#    'start': None,
#    'word': 'V'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 152,
#    'score': 0.99990094,
#    'start': None,
#    'word': '##AS'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 153,
#    'score': 0.9998982,
#    'start': None,
#    'word': '##CO'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 154,
#    'score': 0.9999001,
#    'start': None,
#    'word': '##N'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 155,
#    'score': 0.9998988,
#    'start': None,
#    'word': '##CE'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 156,
#    'score': 0.99989724,
#    'start': None,
#    'word': '##LO'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 157,
#    'score': 0.9998908,
#    'start': None,
#    'word': '##S'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 158,
#    'score': 0.9998838,
#    'start': None,
#    'word': 'CR'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 159,
#    'score': 0.99988806,
#    'start': None,
#    'word': '##U'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 160,
#    'score': 0.9998369,
#    'start': None,
#    'word': '##Z'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 172,
#    'score': 0.59226924,
#    'start': None,
#    'word': '[UNK]'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 173,
#    'score': 0.75500184,
#    'start': None,
#    'word': 'Zona'},
#   {'end': None,
#    'entity': 'B-LOCAL',
#    'index': 175,
#    'score': 0.99546695,
#    'start': None,
#    'word': 'Can'},
#   {'end': None,
#    'entity': 'B-LOCAL',
#    'index': 176,
#    'score': 0.99711096,
#    'start': None,
#    'word': '##ind'},
#   {'end': None,
#    'entity': 'B-LOCAL',
#    'index': 177,
#    'score': 0.9941713,
#    'start': None,
#    'word': '##é'},
#   {'end': None,
#    'entity': 'B-LOCAL',
#    'index': 178,
#    'score': 0.9543733,
#    'start': None,
#    'word': '/'},
#   {'end': None,
#    'entity': 'B-LOCAL',
#    'index': 179,
#    'score': 0.9664239,
#    'start': None,
#    'word': 'CE'}],
#  [{'end': None,
#    'entity': 'B-LEGISLACAO',
#    'index': 40,
#    'score': 0.99946004,
#    'start': None,
#    'word': 'art'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 41,
#    'score': 0.99939096,
#    'start': None,
#    'word': '.'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 42,
#    'score': 0.99920267,
#    'start': None,
#    'word': '36'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 43,
#    'score': 0.9996611,
#    'start': None,
#    'word': ','},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 44,
#    'score': 0.9997309,
#    'start': None,
#    'word': '§'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 45,
#    'score': 0.99962425,
#    'start': None,
#    'word': '[UNK]'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 46,
#    'score': 0.99966,
#    'start': None,
#    'word': ','},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 47,
#    'score': 0.9996486,
#    'start': None,
#    'word': 'da'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 48,
#    'score': 0.9995863,
#    'start': None,
#    'word': 'Lei'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 49,
#    'score': 0.9993926,
#    'start': None,
#    'word': '9'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 50,
#    'score': 0.9994981,
#    'start': None,
#    'word': '.'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 51,
#    'score': 0.9995172,
#    'start': None,
#    'word': '50'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 52,
#    'score': 0.99948585,
#    'start': None,
#    'word': '##4'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 53,
#    'score': 0.99926084,
#    'start': None,
#    'word': '/'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 54,
#    'score': 0.9991386,
#    'start': None,
#    'word': '97'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 61,
#    'score': 0.9989178,
#    'start': None,
#    'word': 'Promo'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 62,
#    'score': 0.99922585,
#    'start': None,
#    'word': '##toria'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 63,
#    'score': 0.9952324,
#    'start': None,
#    'word': 'Eleitoral'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 64,
#    'score': 0.99769294,
#    'start': None,
#    'word': 'da'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 65,
#    'score': 0.9991492,
#    'start': None,
#    'word': '[UNK]'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 66,
#    'score': 0.9993343,
#    'start': None,
#    'word': 'Zona'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 67,
#    'score': 0.99921894,
#    'start': None,
#    'word': '/'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 68,
#    'score': 0.99942267,
#    'start': None,
#    'word': 'CE'}],
#  [{'end': None,
#    'entity': 'B-PESSOA',
#    'index': 1,
#    'score': 0.9712327,
#    'start': None,
#    'word': 'Can'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 2,
#    'score': 0.97102106,
#    'start': None,
#    'word': '##ind'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 3,
#    'score': 0.977221,
#    'start': None,
#    'word': '##é'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 29,
#    'score': 0.93677944,
#    'start': None,
#    'word': 'Insta'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 30,
#    'score': 0.95223826,
#    'start': None,
#    'word': '##gram'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 41,
#    'score': 0.6034735,
#    'start': None,
#    'word': 'il'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 42,
#    'score': 0.68814117,
#    'start': None,
#    'word': '##om'}],
#  [{'end': None,
#    'entity': 'B-LEGISLACAO',
#    'index': 39,
#    'score': 0.9994918,
#    'start': None,
#    'word': 'art'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 40,
#    'score': 0.999129,
#    'start': None,
#    'word': '.'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 41,
#    'score': 0.99908924,
#    'start': None,
#    'word': '36'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 42,
#    'score': 0.9990644,
#    'start': None,
#    'word': '-'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 43,
#    'score': 0.9990018,
#    'start': None,
#    'word': 'A'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 44,
#    'score': 0.99949706,
#    'start': None,
#    'word': 'da'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 45,
#    'score': 0.99946624,
#    'start': None,
#    'word': 'Lei'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 46,
#    'score': 0.99933416,
#    'start': None,
#    'word': '9'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 47,
#    'score': 0.9994361,
#    'start': None,
#    'word': '.'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 48,
#    'score': 0.99943763,
#    'start': None,
#    'word': '50'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 49,
#    'score': 0.99945074,
#    'start': None,
#    'word': '##4'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 50,
#    'score': 0.99915624,
#    'start': None,
#    'word': '/'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 51,
#    'score': 0.9991671,
#    'start': None,
#    'word': '97'},
#   {'end': None,
#    'entity': 'B-LEGISLACAO',
#    'index': 99,
#    'score': 0.9994784,
#    'start': None,
#    'word': 'art'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 100,
#    'score': 0.99873775,
#    'start': None,
#    'word': '.'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 101,
#    'score': 0.9990138,
#    'start': None,
#    'word': '36'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 102,
#    'score': 0.9989642,
#    'start': None,
#    'word': '-'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 103,
#    'score': 0.99897134,
#    'start': None,
#    'word': 'A'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 104,
#    'score': 0.9993857,
#    'start': None,
#    'word': 'da'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 105,
#    'score': 0.9993969,
#    'start': None,
#    'word': 'Lei'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 106,
#    'score': 0.9992242,
#    'start': None,
#    'word': '[UNK]'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 107,
#    'score': 0.99923897,
#    'start': None,
#    'word': '9'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 108,
#    'score': 0.99939823,
#    'start': None,
#    'word': '.'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 109,
#    'score': 0.99940443,
#    'start': None,
#    'word': '50'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 110,
#    'score': 0.99942636,
#    'start': None,
#    'word': '##4'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 111,
#    'score': 0.9991456,
#    'start': None,
#    'word': '/'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 112,
#    'score': 0.99919635,
#    'start': None,
#    'word': '97'}],
#  [],
#  [],
#  [],
#  [{'end': None,
#    'entity': 'B-LOCAL',
#    'index': 27,
#    'score': 0.577895,
#    'start': None,
#    'word': 'assentamento'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 47,
#    'score': 0.9965127,
#    'start': None,
#    'word': 'Il'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 48,
#    'score': 0.99690646,
#    'start': None,
#    'word': '##om'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 49,
#    'score': 0.99639577,
#    'start': None,
#    'word': '##ar'},
#   {'end': None,
#    'entity': 'B-LOCAL',
#    'index': 56,
#    'score': 0.9943779,
#    'start': None,
#    'word': 'Can'},
#   {'end': None,
#    'entity': 'B-LOCAL',
#    'index': 57,
#    'score': 0.99640757,
#    'start': None,
#    'word': '##ind'},
#   {'end': None,
#    'entity': 'B-LOCAL',
#    'index': 58,
#    'score': 0.9886579,
#    'start': None,
#    'word': '##é'},
#   {'end': None,
#    'entity': 'B-LOCAL',
#    'index': 68,
#    'score': 0.96786433,
#    'start': None,
#    'word': 'Can'},
#   {'end': None,
#    'entity': 'B-LOCAL',
#    'index': 69,
#    'score': 0.99002445,
#    'start': None,
#    'word': '##ind'},
#   {'end': None,
#    'entity': 'B-LOCAL',
#    'index': 70,
#    'score': 0.94368166,
#    'start': None,
#    'word': '##é'}],
#  [],
#  [{'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 30,
#    'score': 0.7977132,
#    'start': None,
#    'word': 'I'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 31,
#    'score': 0.82532483,
#    'start': None,
#    'word': '##L'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 32,
#    'score': 0.7467757,
#    'start': None,
#    'word': '##IO'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 33,
#    'score': 0.67267346,
#    'start': None,
#    'word': '##MA'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 34,
#    'score': 0.7916356,
#    'start': None,
#    'word': '##R'},
#   {'end': None,
#    'entity': 'B-LOCAL',
#    'index': 38,
#    'score': 0.9948596,
#    'start': None,
#    'word': 'Can'},
#   {'end': None,
#    'entity': 'B-LOCAL',
#    'index': 39,
#    'score': 0.99693394,
#    'start': None,
#    'word': '##ind'},
#   {'end': None,
#    'entity': 'B-LOCAL',
#    'index': 40,
#    'score': 0.98837936,
#    'start': None,
#    'word': '##é'}],
#  [{'end': None,
#    'entity': 'B-LOCAL',
#    'index': 35,
#    'score': 0.9912493,
#    'start': None,
#    'word': 'interior'},
#   {'end': None,
#    'entity': 'I-LOCAL',
#    'index': 36,
#    'score': 0.9915759,
#    'start': None,
#    'word': 'do'},
#   {'end': None,
#    'entity': 'I-LOCAL',
#    'index': 37,
#    'score': 0.97785646,
#    'start': None,
#    'word': 'Ceará'}],
#  [],
#  [{'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 62,
#    'score': 0.99770564,
#    'start': None,
#    'word': 'T'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 63,
#    'score': 0.9965856,
#    'start': None,
#    'word': '##SE'}],
#  [{'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 92,
#    'score': 0.86496294,
#    'start': None,
#    'word': 'Promo'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 93,
#    'score': 0.83591986,
#    'start': None,
#    'word': '##toria'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 94,
#    'score': 0.6711355,
#    'start': None,
#    'word': 'Eleitoral'}],
#  [{'end': None,
#    'entity': 'B-LOCAL',
#    'index': 19,
#    'score': 0.9949079,
#    'start': None,
#    'word': 'município'},
#   {'end': None,
#    'entity': 'I-LOCAL',
#    'index': 20,
#    'score': 0.8713211,
#    'start': None,
#    'word': 'de'},
#   {'end': None,
#    'entity': 'I-LOCAL',
#    'index': 21,
#    'score': 0.6641886,
#    'start': None,
#    'word': 'Can'},
#   {'end': None,
#    'entity': 'I-LOCAL',
#    'index': 22,
#    'score': 0.71379435,
#    'start': None,
#    'word': '##ind'},
#   {'end': None,
#    'entity': 'I-LOCAL',
#    'index': 23,
#    'score': 0.9066679,
#    'start': None,
#    'word': '##é'}],
#  [{'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 4,
#    'score': 0.984097,
#    'start': None,
#    'word': 'Procurador'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 5,
#    'score': 0.9909554,
#    'start': None,
#    'word': '##ia'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 6,
#    'score': 0.99087584,
#    'start': None,
#    'word': 'Regional'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 7,
#    'score': 0.9944042,
#    'start': None,
#    'word': 'Eleitoral'},
#   {'end': None,
#    'entity': 'B-LEGISLACAO',
#    'index': 31,
#    'score': 0.9995522,
#    'start': None,
#    'word': 'art'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 32,
#    'score': 0.9994617,
#    'start': None,
#    'word': '.'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 33,
#    'score': 0.99927574,
#    'start': None,
#    'word': '36'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 34,
#    'score': 0.99970007,
#    'start': None,
#    'word': ','},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 35,
#    'score': 0.99977463,
#    'start': None,
#    'word': '§'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 36,
#    'score': 0.99971634,
#    'start': None,
#    'word': '[UNK]'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 37,
#    'score': 0.9997185,
#    'start': None,
#    'word': ','},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 38,
#    'score': 0.99966633,
#    'start': None,
#    'word': 'da'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 39,
#    'score': 0.999652,
#    'start': None,
#    'word': 'Lei'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 40,
#    'score': 0.9994623,
#    'start': None,
#    'word': '9'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 41,
#    'score': 0.99952424,
#    'start': None,
#    'word': '.'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 42,
#    'score': 0.9995432,
#    'start': None,
#    'word': '50'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 43,
#    'score': 0.99952245,
#    'start': None,
#    'word': '##4'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 44,
#    'score': 0.9993174,
#    'start': None,
#    'word': '/'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 45,
#    'score': 0.99924517,
#    'start': None,
#    'word': '97'},
#   {'end': None,
#    'entity': 'B-LEGISLACAO',
#    'index': 65,
#    'score': 0.9993337,
#    'start': None,
#    'word': 'art'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 66,
#    'score': 0.9991985,
#    'start': None,
#    'word': '.'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 67,
#    'score': 0.99927706,
#    'start': None,
#    'word': '36'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 68,
#    'score': 0.9992347,
#    'start': None,
#    'word': '-'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 69,
#    'score': 0.9991658,
#    'start': None,
#    'word': 'A'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 70,
#    'score': 0.99944645,
#    'start': None,
#    'word': 'da'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 71,
#    'score': 0.99947804,
#    'start': None,
#    'word': 'Lei'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 72,
#    'score': 0.99931574,
#    'start': None,
#    'word': '9'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 73,
#    'score': 0.99939156,
#    'start': None,
#    'word': '.'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 74,
#    'score': 0.99949014,
#    'start': None,
#    'word': '50'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 75,
#    'score': 0.99948573,
#    'start': None,
#    'word': '##4'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 76,
#    'score': 0.999141,
#    'start': None,
#    'word': '/'},
#   {'end': None,
#    'entity': 'I-LEGISLACAO',
#    'index': 77,
#    'score': 0.9991792,
#    'start': None,
#    'word': '97'},
#   {'end': None,
#    'entity': 'B-LOCAL',
#    'index': 99,
#    'score': 0.9984425,
#    'start': None,
#    'word': 'Fortaleza'},
#   {'end': None,
#    'entity': 'B-TEMPO',
#    'index': 101,
#    'score': 0.9993948,
#    'start': None,
#    'word': '28'},
#   {'end': None,
#    'entity': 'I-TEMPO',
#    'index': 102,
#    'score': 0.9997023,
#    'start': None,
#    'word': 'de'},
#   {'end': None,
#    'entity': 'I-TEMPO',
#    'index': 103,
#    'score': 0.99962103,
#    'start': None,
#    'word': 'maio'},
#   {'end': None,
#    'entity': 'I-TEMPO',
#    'index': 104,
#    'score': 0.99949265,
#    'start': None,
#    'word': 'de'},
#   {'end': None,
#    'entity': 'I-TEMPO',
#    'index': 105,
#    'score': 0.9992532,
#    'start': None,
#    'word': '202'},
#   {'end': None,
#    'entity': 'I-TEMPO',
#    'index': 106,
#    'score': 0.9981192,
#    'start': None,
#    'word': '##4'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 121,
#    'score': 0.9995245,
#    'start': None,
#    'word': 'D'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 122,
#    'score': 0.9996822,
#    'start': None,
#    'word': '##AN'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 123,
#    'score': 0.99974674,
#    'start': None,
#    'word': '##I'},
#   {'end': None,
#    'entity': 'B-PESSOA',
#    'index': 124,
#    'score': 0.9996897,
#    'start': None,
#    'word': '##EL'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 125,
#    'score': 0.9998716,
#    'start': None,
#    'word': 'CA'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 126,
#    'score': 0.999863,
#    'start': None,
#    'word': '##R'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 127,
#    'score': 0.9998821,
#    'start': None,
#    'word': '##VA'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 128,
#    'score': 0.99985945,
#    'start': None,
#    'word': '##L'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 129,
#    'score': 0.999858,
#    'start': None,
#    'word': '##HO'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 130,
#    'score': 0.9998522,
#    'start': None,
#    'word': 'CA'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 131,
#    'score': 0.9998361,
#    'start': None,
#    'word': '##R'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 132,
#    'score': 0.99984145,
#    'start': None,
#    'word': '##N'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 133,
#    'score': 0.9998528,
#    'start': None,
#    'word': '##EI'},
#   {'end': None,
#    'entity': 'I-PESSOA',
#    'index': 134,
#    'score': 0.99972576,
#    'start': None,
#    'word': '##RO'}],
#  [{'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 18,
#    'score': 0.99955565,
#    'start': None,
#    'word': 'T'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 19,
#    'score': 0.9996215,
#    'start': None,
#    'word': '##RI'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 20,
#    'score': 0.99963486,
#    'start': None,
#    'word': '##B'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 21,
#    'score': 0.9996247,
#    'start': None,
#    'word': '##UN'},
#   {'end': None,
#    'entity': 'B-ORGANIZACAO',
#    'index': 22,
#    'score': 0.9995913,
#    'start': None,
#    'word': '##AL'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 23,
#    'score': 0.9998623,
#    'start': None,
#    'word': 'R'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 24,
#    'score': 0.99986005,
#    'start': None,
#    'word': '##E'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 25,
#    'score': 0.99985445,
#    'start': None,
#    'word': '##G'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 26,
#    'score': 0.99985194,
#    'start': None,
#    'word': '##IO'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 27,
#    'score': 0.99985063,
#    'start': None,
#    'word': '##NA'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 28,
#    'score': 0.99985707,
#    'start': None,
#    'word': '##L'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 29,
#    'score': 0.99985623,
#    'start': None,
#    'word': 'E'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 30,
#    'score': 0.9998442,
#    'start': None,
#    'word': '##L'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 31,
#    'score': 0.9998542,
#    'start': None,
#    'word': '##EI'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 32,
#    'score': 0.9998487,
#    'start': None,
#    'word': '##TO'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 33,
#    'score': 0.9998661,
#    'start': None,
#    'word': '##RA'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 34,
#    'score': 0.9998535,
#    'start': None,
#    'word': '##L'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 35,
#    'score': 0.99978584,
#    'start': None,
#    'word': 'DO'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 36,
#    'score': 0.9998153,
#    'start': None,
#    'word': 'CE'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 37,
#    'score': 0.99979216,
#    'start': None,
#    'word': '##AR'},
#   {'end': None,
#    'entity': 'I-ORGANIZACAO',
#    'index': 38,
#    'score': 0.99977,
#    'start': None,
#    'word': '##Á'},
#   {'end': None,
#    'entity': 'B-JURISPRUDENCIA',
#    'index': 39,
#    'score': 0.9989009,
#    'start': None,
#    'word': 'R'},
#   {'end': None,
#    'entity': 'B-JURISPRUDENCIA',
#    'index': 40,
#    'score': 0.9991799,
#    'start': None,
#    'word': '##EC'},
#   {'end': None,
#    'entity': 'B-JURISPRUDENCIA',
#    'index': 41,
#    'score': 0.999124,
#    'start': None,
#    'word': '##UR'},
#   {'end': None,
#    'entity': 'B-JURISPRUDENCIA',
#    'index': 42,
#    'score': 0.99915123,
#    'start': None,
#    'word': '##SO'},
#   {'end': None,
#    'entity': 'I-JURISPRUDENCIA',
#    'index': 43,
#    'score': 0.9993686,
#    'start': None,
#    'word': 'E'},
#   {'end': None,
#    'entity': 'I-JURISPRUDENCIA',
#    'index': 44,
#    'score': 0.9993411,
#    'start': None,
#    'word': '##L'},
#   {'end': None,
#    'entity': 'I-JURISPRUDENCIA',
#    'index': 45,
#    'score': 0.99953437,
#    'start': None,
#    'word': '##EI'},
#   {'end': None,
#    'entity': 'I-JURISPRUDENCIA',
#    'index': 46,
#    'score': 0.9995927,
#    'start': None,
#    'word': '##TO'},
#   {'end': None,
#    'entity': 'I-JURISPRUDENCIA',
#    'index': 47,
#    'score': 0.99964404,
#    'start': None,
#    'word': '##RA'},
#   {'end': None,
#    'entity': 'I-JURISPRUDENCIA',
#    'index': 48,
#    'score': 0.99964905,
#    'start': None,
#    'word': '##L'},
#   {'end': None,
#    'entity': 'I-JURISPRUDENCIA',
#    'index': 49,
#    'score': 0.9996903,
#    'start': None,
#    'word': 'N'},
#   {'end': None,
#    'entity': 'I-JURISPRUDENCIA',
#    'index': 50,
#    'score': 0.9997043,
#    'start': None,
#    'word': '.'},
#   {'end': None,
#    'entity': 'I-JURISPRUDENCIA',
#    'index': 51,
#    'score': 0.9997292,
#    'start': None,
#    'word': '06'},
#   {'end': None,
#    'entity': 'I-JURISPRUDENCIA',
#    'index': 52,
#    'score': 0.99972194,
#    'start': None,
#    'word': '##000'},
#   {'end': None,
#    'entity': 'I-JURISPRUDENCIA',
#    'index': 53,
#    'score': 0.9996983,
#    'start': None,
#    'word': '##12'},
#   {'end': None,
#    'entity': 'I-JURISPRUDENCIA',
#    'index': 54,
#    'score': 0.9997553,
#    'start': None,
#    'word': '-'},
#   {'end': None,
#    'entity': 'I-JURISPRUDENCIA',
#    'index': 55,
#    'score': 0.9997043,
#    'start': None,
#    'word': '49'},
#   {'end': None,
#    'entity': 'I-JURISPRUDENCIA',
#    'index': 56,
#    'score': 0.99971443,
#    'start': None,
#    'word': '.'},
#   {'end': None,
#    'entity': 'I-JURISPRUDENCIA',
#    'index': 57,
#    'score': 0.9997149,
#    'start': None,
#    'word': '202'},
#   {'end': None,
#    'entity': 'I-JURISPRUDENCIA',
#    'index': 58,
#    'score': 0.999694,
#    'start': None,
#    'word': '##4'},
#   {'end': None,
#    'entity': 'I-JURISPRUDENCIA',
#    'index': 59,
#    'score': 0.99971646,
#    'start': None,
#    'word': '.'},
#   {'end': None,
#    'entity': 'I-JURISPRUDENCIA',
#    'index': 60,
#    'score': 0.99966764,
#    'start': None,
#    'word': '6'},
#   {'end': None,
#    'entity': 'I-JURISPRUDENCIA',
#    'index': 61,
#    'score': 0.99966633,
#    'start': None,
#    'word': '.'},
#   {'end': None,
#    'entity': 'I-JURISPRUDENCIA',
#    'index': 62,
#    'score': 0.9996056,
#    'start': None,
#    'word': '06'},
#   {'end': None,
#    'entity': 'I-JURISPRUDENCIA',
#    'index': 63,
#    'score': 0.99964595,
#    'start': None,
#    'word': '.'},
#   {'end': None,
#    'entity': 'I-JURISPRUDENCIA',
#    'index': 64,
#    'score': 0.9995534,
#    'start': None,
#    'word': '00'},
#   {'end': None,
#    'entity': 'I-JURISPRUDENCIA',
#    'index': 65,
#    'score': 0.99955136,
#    'start': None,
#    'word': '##33'},
#   {'end': None,
#    'entity': 'B-LOCAL',
#    'index': 71,
#    'score': 0.9983835,
#    'start': None,
#    'word': 'CA'},
#   {'end': None,
#    'entity': 'B-LOCAL',
#    'index': 72,
#    'score': 0.99871683,
#    'start': None,
#    'word': '##N'},
#   {'end': None,
#    'entity': 'B-LOCAL',
#    'index': 73,
#    'score': 0.99886703,
#    'start': None,
#    'word': '##IN'},
#   {'end': None,
#    'entity': 'B-LOCAL',
#    'index': 74,
#    'score': 0.99876463,
#    'start': None,
#    'word': '##D'},
#   {'end': None,
#    'entity': 'B-LOCAL',
#    'index': 75,
#    'score': 0.9985751,
#    'start': None,
#    'word': '##É'},
#   {'end': None,
#    'entity': 'B-LOCAL',
#    'index': 76,
#    'score': 0.9988392,
#    'start': None,
#    'word': '/'},
#   {'end': None,
#    'entity': 'B-LOCAL',
#    'index': 77,
#    'score': 0.9971311,
#    'start': None,
#    'word': 'CE'}]]

# %%
words = [[ent['word'], ent['entity']] for ent in all_entities_flattened]
print(list(words))
# Out:
# [['AN', 'B-PESSOA'], ['##T', 'B-PESSOA'], ['##Ô', 'B-PESSOA'], ['##N', 'B-PESSOA'], ['##IO', 'B-PESSOA'], ['I', 'I-PESSOA'], ['##LO', 'I-PESSOA'], ['##MA', 'I-PESSOA'], ['##R', 'I-PESSOA'], ['V', 'I-PESSOA'], ['##AS', 'I-PESSOA'], ['##CO', 'I-PESSOA'], ['##N', 'I-PESSOA'], ['##CE', 'I-PESSOA'], ['##LO', 'I-PESSOA'], ['##S', 'I-PESSOA'], ['CR', 'I-PESSOA'], ['##U', 'I-PESSOA'], ['##Z', 'I-PESSOA'], ['F', 'B-PESSOA'], ['##RA', 'B-PESSOA'], ['##N', 'B-PESSOA'], ['##CI', 'B-PESSOA'], ['##SC', 'B-PESSOA'], ['##O', 'B-PESSOA'], ['J', 'I-PESSOA'], ['##AR', 'I-PESSOA'], ['##DE', 'I-PESSOA'], ['##L', 'I-PESSOA'], ['R', 'I-PESSOA'], ['##O', 'I-PESSOA'], ['##DR', 'I-PESSOA'], ['##IG', 'I-PESSOA'], ['##U', 'I-PESSOA'], ['##ES', 'I-PESSOA'], ['DE', 'I-PESSOA'], ['SO', 'I-PESSOA'], ['##US', 'I-PESSOA'], ['##A', 'I-PESSOA'], ['O', 'B-ORGANIZACAO'], ['##AB', 'B-ORGANIZACAO'], ['CA', 'B-PESSOA'], ['##VA', 'B-PESSOA'], ['##LC', 'B-PESSOA'], ['##AN', 'B-PESSOA'], ['##TE', 'B-PESSOA'], ['M', 'I-PESSOA'], ['##EN', 'I-PESSOA'], ['##DO', 'I-PESSOA'], ['##N', 'I-PESSOA'], ['##Ç', 'I-PESSOA'], ['##A', 'I-PESSOA'], ['VI', 'I-PESSOA'], ['##EI', 'I-PESSOA'], ['##RA', 'I-PESSOA'], ['O', 'B-ORGANIZACAO'], ['##AB', 'B-ORGANIZACAO'], ['M', 'B-ORGANIZACAO'], ['##IN', 'B-ORGANIZACAO'], ['##IS', 'B-ORGANIZACAO'], ['##T', 'B-ORGANIZACAO'], ['##É', 'B-ORGANIZACAO'], ['##RI', 'B-ORGANIZACAO'], ['##O', 'B-ORGANIZACAO'], ['P', 'I-ORGANIZACAO'], ['##Ú', 'I-ORGANIZACAO'], ['##B', 'I-ORGANIZACAO'], ['##L', 'I-ORGANIZACAO'], ['##IC', 'I-ORGANIZACAO'], ['##O', 'I-ORGANIZACAO'], ['E', 'I-ORGANIZACAO'], ['##L', 'I-ORGANIZACAO'], ['##EI', 'I-ORGANIZACAO'], ['##TO', 'I-ORGANIZACAO'], ['##RA', 'I-ORGANIZACAO'], ['##L', 'I-ORGANIZACAO'], ['AN', 'B-PESSOA'], ['##T', 'B-PESSOA'], ['##Ô', 'B-PESSOA'], ['##N', 'B-PESSOA'], ['##IO', 'B-PESSOA'], ['I', 'I-PESSOA'], ['##LO', 'I-PESSOA'], ['##MA', 'I-PESSOA'], ['##R', 'I-PESSOA'], ['V', 'I-PESSOA'], ['##AS', 'I-PESSOA'], ['##CO', 'I-PESSOA'], ['##N', 'I-PESSOA'], ['##CE', 'I-PESSOA'], ['##LO', 'I-PESSOA'], ['##S', 'I-PESSOA'], ['CR', 'I-PESSOA'], ['##U', 'I-PESSOA'], ['##Z', 'I-PESSOA'], ['[UNK]', 'B-ORGANIZACAO'], ['Zona', 'I-ORGANIZACAO'], ['Can', 'B-LOCAL'], ['##ind', 'B-LOCAL'], ['##é', 'B-LOCAL'], ['/', 'B-LOCAL'], ['CE', 'B-LOCAL'], ['art', 'B-LEGISLACAO'], ['.', 'I-LEGISLACAO'], ['36', 'I-LEGISLACAO'], [',', 'I-LEGISLACAO'], ['§', 'I-LEGISLACAO'], ['[UNK]', 'I-LEGISLACAO'], [',', 'I-LEGISLACAO'], ['da', 'I-LEGISLACAO'], ['Lei', 'I-LEGISLACAO'], ['9', 'I-LEGISLACAO'], ['.', 'I-LEGISLACAO'], ['50', 'I-LEGISLACAO'], ['##4', 'I-LEGISLACAO'], ['/', 'I-LEGISLACAO'], ['97', 'I-LEGISLACAO'], ['Promo', 'B-ORGANIZACAO'], ['##toria', 'B-ORGANIZACAO'], ['Eleitoral', 'I-ORGANIZACAO'], ['da', 'I-ORGANIZACAO'], ['[UNK]', 'I-ORGANIZACAO'], ['Zona', 'I-ORGANIZACAO'], ['/', 'I-ORGANIZACAO'], ['CE', 'I-ORGANIZACAO'], ['Can', 'B-PESSOA'], ['##ind', 'B-PESSOA'], ['##é', 'B-PESSOA'], ['Insta', 'B-ORGANIZACAO'], ['##gram', 'B-ORGANIZACAO'], ['il', 'B-PESSOA'], ['##om', 'B-PESSOA'], ['art', 'B-LEGISLACAO'], ['.', 'I-LEGISLACAO'], ['36', 'I-LEGISLACAO'], ['-', 'I-LEGISLACAO'], ['A', 'I-LEGISLACAO'], ['da', 'I-LEGISLACAO'], ['Lei', 'I-LEGISLACAO'], ['9', 'I-LEGISLACAO'], ['.', 'I-LEGISLACAO'], ['50', 'I-LEGISLACAO'], ['##4', 'I-LEGISLACAO'], ['/', 'I-LEGISLACAO'], ['97', 'I-LEGISLACAO'], ['art', 'B-LEGISLACAO'], ['.', 'I-LEGISLACAO'], ['36', 'I-LEGISLACAO'], ['-', 'I-LEGISLACAO'], ['A', 'I-LEGISLACAO'], ['da', 'I-LEGISLACAO'], ['Lei', 'I-LEGISLACAO'], ['[UNK]', 'I-LEGISLACAO'], ['9', 'I-LEGISLACAO'], ['.', 'I-LEGISLACAO'], ['50', 'I-LEGISLACAO'], ['##4', 'I-LEGISLACAO'], ['/', 'I-LEGISLACAO'], ['97', 'I-LEGISLACAO'], ['assentamento', 'B-LOCAL'], ['Il', 'B-PESSOA'], ['##om', 'B-PESSOA'], ['##ar', 'B-PESSOA'], ['Can', 'B-LOCAL'], ['##ind', 'B-LOCAL'], ['##é', 'B-LOCAL'], ['Can', 'B-LOCAL'], ['##ind', 'B-LOCAL'], ['##é', 'B-LOCAL'], ['I', 'B-ORGANIZACAO'], ['##L', 'B-ORGANIZACAO'], ['##IO', 'B-ORGANIZACAO'], ['##MA', 'B-ORGANIZACAO'], ['##R', 'B-ORGANIZACA ...

# %%
full_words = list()

for word in words:
    w = word[0]
    e = word[1]
    if len(word[0]) < 3 or word[0][:2] != '##':
        full_words.append([w, e])
    else:
        full_words[-1][0] = full_words[-1][0] + w[2:]

print(full_words)
# Out:
# [['ANTÔNIO', 'B-PESSOA'], ['ILOMAR', 'I-PESSOA'], ['VASCONCELOS', 'I-PESSOA'], ['CRUZ', 'I-PESSOA'], ['FRANCISCO', 'B-PESSOA'], ['JARDEL', 'I-PESSOA'], ['RODRIGUES', 'I-PESSOA'], ['DE', 'I-PESSOA'], ['SOUSA', 'I-PESSOA'], ['OAB', 'B-ORGANIZACAO'], ['CAVALCANTE', 'B-PESSOA'], ['MENDONÇA', 'I-PESSOA'], ['VIEIRA', 'I-PESSOA'], ['OAB', 'B-ORGANIZACAO'], ['MINISTÉRIO', 'B-ORGANIZACAO'], ['PÚBLICO', 'I-ORGANIZACAO'], ['ELEITORAL', 'I-ORGANIZACAO'], ['ANTÔNIO', 'B-PESSOA'], ['ILOMAR', 'I-PESSOA'], ['VASCONCELOS', 'I-PESSOA'], ['CRUZ', 'I-PESSOA'], ['[UNK]', 'B-ORGANIZACAO'], ['Zona', 'I-ORGANIZACAO'], ['Canindé', 'B-LOCAL'], ['/', 'B-LOCAL'], ['CE', 'B-LOCAL'], ['art', 'B-LEGISLACAO'], ['.', 'I-LEGISLACAO'], ['36', 'I-LEGISLACAO'], [',', 'I-LEGISLACAO'], ['§', 'I-LEGISLACAO'], ['[UNK]', 'I-LEGISLACAO'], [',', 'I-LEGISLACAO'], ['da', 'I-LEGISLACAO'], ['Lei', 'I-LEGISLACAO'], ['9', 'I-LEGISLACAO'], ['.', 'I-LEGISLACAO'], ['504', 'I-LEGISLACAO'], ['/', 'I-LEGISLACAO'], ['97', 'I-LEGISLACAO'], ['Promotoria', 'B-ORGANIZACAO'], ['Eleitoral', 'I-ORGANIZACAO'], ['da', 'I-ORGANIZACAO'], ['[UNK]', 'I-ORGANIZACAO'], ['Zona', 'I-ORGANIZACAO'], ['/', 'I-ORGANIZACAO'], ['CE', 'I-ORGANIZACAO'], ['Canindé', 'B-PESSOA'], ['Instagram', 'B-ORGANIZACAO'], ['ilom', 'B-PESSOA'], ['art', 'B-LEGISLACAO'], ['.', 'I-LEGISLACAO'], ['36', 'I-LEGISLACAO'], ['-', 'I-LEGISLACAO'], ['A', 'I-LEGISLACAO'], ['da', 'I-LEGISLACAO'], ['Lei', 'I-LEGISLACAO'], ['9', 'I-LEGISLACAO'], ['.', 'I-LEGISLACAO'], ['504', 'I-LEGISLACAO'], ['/', 'I-LEGISLACAO'], ['97', 'I-LEGISLACAO'], ['art', 'B-LEGISLACAO'], ['.', 'I-LEGISLACAO'], ['36', 'I-LEGISLACAO'], ['-', 'I-LEGISLACAO'], ['A', 'I-LEGISLACAO'], ['da', 'I-LEGISLACAO'], ['Lei', 'I-LEGISLACAO'], ['[UNK]', 'I-LEGISLACAO'], ['9', 'I-LEGISLACAO'], ['.', 'I-LEGISLACAO'], ['504', 'I-LEGISLACAO'], ['/', 'I-LEGISLACAO'], ['97', 'I-LEGISLACAO'], ['assentamento', 'B-LOCAL'], ['Ilomar', 'B-PESSOA'], ['Canindé', 'B-LOCAL'], ['Canindé', 'B-LOCAL'], ['ILIOMAR', 'B-ORGANIZACAO'], ['Canindé', 'B-LOCAL'], ['interior', 'B-LOCAL'], ['do', 'I-LOCAL'], ['Ceará', 'I-LOCAL'], ['TSE', 'B-ORGANIZACAO'], ['Promotoria', 'B-ORGANIZACAO'], ['Eleitoral', 'I-ORGANIZACAO'], ['município', 'B-LOCAL'], ['de', 'I-LOCAL'], ['Canindé', 'I-LOCAL'], ['Procuradoria', 'B-ORGANIZACAO'], ['Regional', 'I-ORGANIZACAO'], ['Eleitoral', 'I-ORGANIZACAO'], ['art', 'B-LEGISLACAO'], ['.', 'I-LEGISLACAO'], ['36', 'I-LEGISLACAO'], [',', 'I-LEGISLACAO'], ['§', 'I-LEGISLACAO'], ['[UNK]', 'I-LEGISLACAO'], [',', 'I-LEGISLACAO'], ['da', 'I-LEGISLACAO'], ['Lei', 'I-LEGISLACAO'], ['9', 'I-LEGISLACAO'], ['.', 'I-LEGISLACAO'], ['504', 'I-LEGISLACAO'], ['/', 'I-LEGISLACAO'], ['97', 'I-LEGISLACAO'], ['art', 'B-LEGISLACAO'], ['.', 'I-LEGISLACAO'], ['36', 'I-LEGISLACAO'], ['-', 'I-LEGISLACAO'], ['A', 'I-LEGISLACAO'], ['da', 'I-LEGISLACAO'], ['Lei', 'I-LEGISLACAO'], ['9', 'I-LEGISLACAO'], ['.', 'I-LEGISLACAO'], ['504', 'I-LEGISLACAO'], ['/', 'I-LEGISLACAO'], ['97', 'I-LEGISLACAO'], ['Fortaleza', 'B-LOCAL'], ['28', 'B-TEMPO'], ['de', 'I-TEMPO'], ['maio', 'I-TEMPO'], ['de', 'I-TEMPO'], ['2024', 'I-TEMPO'], ['DANIEL', 'B-PESSOA'], ['CARVALHO', 'I-PESSOA'], ['CARNEIRO', 'I-PESSOA'], ['TRIBUNAL', 'B-ORGANIZACAO'], ['REGIONAL', 'I-ORGANIZACAO'], ['ELEITORAL', 'I-ORGANIZACAO'], ['DO', 'I-ORGANIZACAO'], ['CEARÁ', 'I-ORGANIZACAO'], ['RECURSO', 'B-JURISPRUDENCIA'], ['ELEITORAL', 'I-JURISPRUDENCIA'], ['N', 'I-JURISPRUDENCIA'], ['.', 'I-JURISPRUDENCIA'], ['0600012', 'I-JURISPRUDENCIA'], ['-', 'I-JURISPRUDENCIA'], ['49', 'I-JURISPRUDENCIA'], ['.', 'I-JURISPRUDENCIA'], ['2024', 'I-JURISPRUDENCIA'], ['.', 'I-JURISPRUDENCIA'], ['6', 'I-JURISPRUDENCIA'], ['.', 'I-JURISPRUDENCIA'], ['06', 'I-JURISPRUDENCIA'], ['.', 'I-JURISPRUDENCIA'], ['0033', 'I-JURISPRUDENCIA'], ['CANINDÉ', 'B-LOCAL'], ['/', 'B-LOCAL'], ['CE', 'B-LOCAL']]

# %%
from functools import reduce


topics = [word for word in full_words]
full_topics = []

for word in topics:
    if word[1][0] == 'B':
        full_topics.append([word[0], word[1][2:]])
    elif word[1][0] == 'I':
        full_topics[-1][0] = full_topics[-1][0] + ' ' + word[0]

full_topics_filtered = list(filter(lambda x: x not in full_topics, full_topics))
full_topics_text = reduce(lambda x, y: x + '\n‒ ' + y[0], full_topics_filtered, '')

print(full_topics_text)

# %%
missing_topics_prompt = PromptTemplate.from_template(
    """
    O resumo do acórdão está incompleto. Por favor, com base nos seguintes tópicos, complete o resumo do acórdão:

    {topics}

    ### Resumo do Acórdão
    {context}
    ### Fim do Resumo

    Resumo corrigido:
    """
)

missing_topics_chain = create_stuff_documents_chain(llm, missing_topics_prompt)
retrieval_chain = create_retrieval_chain(retriever, missing_topics_chain)

chunks = []
for chunk in retrieval_chain.stream({"topics": full_topics, "context": summary}):
    answer = chunk.get('answer', '')
    chunks.append(answer)
    print(answer, end='', flush=True)
